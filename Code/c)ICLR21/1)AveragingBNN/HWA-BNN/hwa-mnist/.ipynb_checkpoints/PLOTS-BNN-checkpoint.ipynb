# %% [markdown]
# # Plots

# %%
import numpy as np
import pandas as pd 
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import pickle
import torch

# %% [markdown]
# ## Cyclical LR

# %%
#Training
sgdcyclical = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_optsgd_lr0.01_bs128_avgp10_cyclical.txt'
sgd = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_optsgd_lr0.01_bs128_avgp10_normal.txt'

hwacyclical = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_opthwa_sgd_lr0.01_bs128_avgp10_cyclical.txt'
hwa = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_opthwa_sgd_lr0.01_bs128_avgp10_normal.txt'

# %%
runsgdcyclical = pd.read_table(sgdcyclical, index_col = 0, sep = '\t')
runsgd = pd.read_table(sgd, index_col = 0, sep = '\t')

runhwacyclical = pd.read_table(hwacyclical, index_col = 0, sep = '\t')
runhwa = pd.read_table(hwa, index_col = 0, sep = '\t')
# Out:
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead.
#
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:4: FutureWarning: read_table is deprecated, use read_csv instead.
#   after removing the cwd from sys.path.
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:5: FutureWarning: read_table is deprecated, use read_csv instead.
#   """

# %%
num_epochs=8
every = len(runsgd['Train Loss'])/num_epochs

#xaxis = range(len(runhwa50['Train Loss']))
xaxis = range(num_epochs)
f, axs = plt.subplots(2,2,figsize=(10,5))
plt.tight_layout()
plt.subplot(1, 2, 1)
plt.plot(xaxis, runsgdcyclical['Train Loss'].iloc[::every], label='SGD cyclical')
plt.plot(xaxis, runsgd['Train Loss'].iloc[::every], label='SGD')

plt.plot(xaxis, runhwacyclical['Train Loss'].iloc[::every], label='HWA cyclical')
plt.plot(xaxis, runhwa['Train Loss'].iloc[::every], label='HWA')

plt.title('Train Loss')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(xaxis, runsgdcyclical['Train Acc.'].iloc[::every], label='SGD cyclical')
plt.plot(xaxis, runsgd['Train Acc.'].iloc[::every], label='SGD')

plt.plot(xaxis, runhwacyclical['Train Acc.'].iloc[::every], label='HWA cyclical')
plt.plot(xaxis, runhwa['Train Acc.'].iloc[::every], label='HWA')

plt.title('Train Acc.')
plt.grid(True)
plt.legend()

# %%
#Training
sgdcyclical = 'checkpoint/checkpoint_MNIST/testlogLeNet5_optsgd_lr0.01_bs128_avgp10_cyclical.txt'
sgd = 'checkpoint/checkpoint_MNIST/testlogLeNet5_optsgd_lr0.01_bs128_avgp10_normal.txt'

hwacyclical = 'checkpoint/checkpoint_MNIST/testlogLeNet5_opthwa_sgd_lr0.01_bs128_avgp10_cyclical.txt'
hwa = 'checkpoint/checkpoint_MNIST/testlogLeNet5_opthwa_sgd_lr0.01_bs128_avgp10_normal.txt'

# %%
num_epochs=8
every = len(runsgd['Test Loss'])/num_epochs

#xaxis = range(len(runhwa50['Train Loss']))
xaxis = range(num_epochs)
f, axs = plt.subplots(2,2,figsize=(10,5))
plt.tight_layout()
plt.subplot(1, 2, 1)
plt.plot(xaxis, runsgdcyclical['Test Loss'].iloc[::every], label='SGD cyclical')
plt.plot(xaxis, runsgd['Test Loss'].iloc[::every], label='SGD')

plt.plot(xaxis, runhwacyclical['Test Loss'].iloc[::every], label='HWA cyclical')
plt.plot(xaxis, runhwa['Test Loss'].iloc[::every], label='HWA')

plt.title('Test Loss')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(xaxis, runsgdcyclical['Test Acc.'].iloc[::every], label='SGD cyclical')
plt.plot(xaxis, runsgd['Test Acc.'].iloc[::every], label='SGD')

plt.plot(xaxis, runhwacyclical['Test Acc.'].iloc[::every], label='HWA cyclical')
plt.plot(xaxis, runhwa['Test Acc.'].iloc[::every], label='HWA')

plt.title('Test Acc.')
plt.grid(True)
plt.legend()

# %%
#Training
sgd = 'checkpoint/checkpoint_MNIST/testlogLeNet5_optsgd_lr0.01_bs128_avgp10.txt'
hwa10 = 'checkpoint/checkpoint_MNIST/testlogLeNet5_opthwa_sgd_lr0.01_bs128_avgp10.txt'
hwa100 = 'checkpoint/checkpoint_MNIST/testlogLeNet5_opthwa_sgd_lr0.01_bs128_avgp100.txt'
hwa50 = 'checkpoint/checkpoint_MNIST/testlogLeNet5_opthwa_sgd_lr0.01_bs128_avgp25.txt'
hwa5 = 'checkpoint/checkpoint_MNIST/testlogLeNet5_opthwa_sgd_lr0.01_bs128_avgp5.txt'

runsgd = pd.read_table(sgd, index_col = 0, sep = '\t')
runhwa10 = pd.read_table(hwa10, index_col = 0, sep = '\t')
runhwa100 = pd.read_table(hwa100, index_col = 0, sep = '\t')
runhwa50 = pd.read_table(hwa50, index_col = 0, sep = '\t')
runhwa5 = pd.read_table(hwa5, index_col = 0, sep = '\t')

num_epochs=9
every = len(runsgd['Test Loss'])/num_epochs

#xaxis = range(len(runhwa50['Train Loss']))
xaxis = range(num_epochs)
f, axs = plt.subplots(2,2,figsize=(10,5))
plt.tight_layout()
plt.subplot(1, 2, 1)
plt.plot(xaxis, runsgd['Test Loss'].iloc[::every], label='SGD')
plt.plot(xaxis, runhwa10['Test Loss'].iloc[::every], label='HWA 10')
plt.plot(xaxis, runhwa100['Test Loss'].iloc[::every], label='HWA 100')
plt.plot(xaxis, runhwa50['Test Loss'].iloc[::every], label='HWA 50')
plt.plot(xaxis, runhwa5['Test Loss'].iloc[::every], label='HWA 5')

plt.title('Test Loss')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(xaxis, runsgd['Test Acc.'].iloc[::every], label='SGD')
plt.plot(xaxis, runhwa10['Test Acc.'].iloc[::every], label='HWA 10')
plt.plot(xaxis, runhwa100['Test Acc.'].iloc[::every], label='HWA 100')
plt.plot(xaxis, runhwa50['Test Acc.'].iloc[::every], label='HWA 50')
plt.plot(xaxis, runhwa5['Test Acc.'].iloc[::every], label='HWA 5')
plt.title('Test Acc.')
plt.grid(True)
plt.legend()
# Out:
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:9: FutureWarning: read_table is deprecated, use read_csv instead.
#   if __name__ == '__main__':
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:10: FutureWarning: read_table is deprecated, use read_csv instead.
#   # Remove the CWD from sys.path while we load stuff.
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:11: FutureWarning: read_table is deprecated, use read_csv instead.
#   # This is added back by InteractiveShellApp.init_path()
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:12: FutureWarning: read_table is deprecated, use read_csv instead.
#   if sys.path[0] == '':
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:13: FutureWarning: read_table is deprecated, use read_csv instead.
#   del sys.path[0]

# %% [markdown]
# ### Training

# %%
adam = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_optadam_lr0.001_bs128.txt'
sgd = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_optsgd_lr0.01_bs128.txt'
hwa = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_opthwa_lr0.001_bs128.txt'
hwasgd = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_opthwa_sgd_lr0.02_bs128.txt'
hwa50 = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_opthwa_lr0.001_bs128_avgp50.txt'
hwa10 = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_opthwa_lr0.001_bs128_avgp10.txt'

runadam = pd.read_table(adam, index_col = 0, sep = '\t')
runsgd = pd.read_table(sgd, index_col = 0, sep = '\t')
runhwa = pd.read_table(hwa, index_col = 0, sep = '\t')
runhwa50 = pd.read_table(hwa50, index_col = 0, sep = '\t')
runhwa10 = pd.read_table(hwa10, index_col = 0, sep = '\t')
runhwasgd = pd.read_table(hwasgd, index_col = 0, sep = '\t')


xaxis = range(len(runhwa50['Train Loss']))
f, axs = plt.subplots(2,2,figsize=(10,5))
plt.tight_layout()
plt.subplot(1, 2, 1)
plt.plot(xaxis, runadam['Train Loss'], label='Adam')
plt.plot(xaxis, runsgd['Train Loss'], label='SGD')
plt.plot(xaxis, runhwa['Train Loss'], label='HWA')
plt.plot(xaxis, runhwa50['Train Loss'], label='HWA 50')
plt.plot(xaxis, runhwa10['Train Loss'], label='HWA 10')
plt.plot(xaxis, runhwasgd['Train Loss'], label='HWA SGD')

plt.title('Train Loss')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(xaxis, runadam['Train Acc.'], label='Adam')
plt.plot(xaxis, runsgd['Train Acc.'], label='SGD')
plt.plot(xaxis, runhwa['Train Acc.'], label='HWA')
plt.plot(xaxis, runhwa50['Train Acc.'], label='HWA 50')
plt.plot(xaxis, runhwa10['Train Acc.'], label='HWA 10')
plt.plot(xaxis, runhwasgd['Train Acc.'], label='HWA SGD')
plt.title('Train Acc.')
plt.grid(True)
plt.legend()
# Out:
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:8: FutureWarning: read_table is deprecated, use read_csv instead.
#
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:9: FutureWarning: read_table is deprecated, use read_csv instead.
#   if __name__ == '__main__':
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:10: FutureWarning: read_table is deprecated, use read_csv instead.
#   # Remove the CWD from sys.path while we load stuff.
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:11: FutureWarning: read_table is deprecated, use read_csv instead.
#   # This is added back by InteractiveShellApp.init_path()
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:12: FutureWarning: read_table is deprecated, use read_csv instead.
#   if sys.path[0] == '':
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:13: FutureWarning: read_table is deprecated, use read_csv instead.
#   del sys.path[0]

# %% [markdown]
# ### More epochs

# %%
#adam = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_optadam_lr0.001_bs128.txt'
#sgd = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_optsgd_lr0.01_bs128.txt'
#hwa = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_opthwa_lr0.001_bs128.txt'
#hwasgd = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_opthwa_sgd_lr0.02_bs128.txt'
hwa50 = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_opthwa_lr0.001_bs128_avgp100.txt'
hwa10 = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_opthwa_lr0.001_bs128_avgp10.txt'

#runadam = pd.read_table(adam, index_col = 0, sep = '\t')
#runsgd = pd.read_table(sgd, index_col = 0, sep = '\t')
#runhwa = pd.read_table(hwa, index_col = 0, sep = '\t')
# runhwasgd = pd.read_table(hwasgd, index_col = 0, sep = '\t')
runhwa50 = pd.read_table(hwa50, index_col = 0, sep = '\t')
runhwa10 = pd.read_table(hwa10, index_col = 0, sep = '\t')


xaxis = range(len(runhwa10['Train Loss']))
f, axs = plt.subplots(2,2,figsize=(10,5))
plt.tight_layout()
plt.subplot(1, 2, 1)
# plt.plot(xaxis, runadam['Train Loss'], label='Adam')
# plt.plot(xaxis, runsgd['Train Loss'], label='SGD')
# plt.plot(xaxis, runhwa['Train Loss'], label='HWA')
plt.plot(xaxis, runhwa50['Train Loss'], label='HWA 50')
plt.plot(xaxis, runhwa10['Train Loss'], label='HWA 10')
# plt.plot(xaxis, runhwasgd['Train Loss'], label='HWA SGD')

plt.title('Train Loss')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
# plt.plot(xaxis, runadam['Train Acc.'], label='Adam')
# plt.plot(xaxis, runsgd['Train Acc.'], label='SGD')
# plt.plot(xaxis, runhwa['Train Acc.'], label='HWA')
plt.plot(xaxis, runhwa50['Train Acc.'], label='HWA 50')
plt.plot(xaxis, runhwa10['Train Acc.'], label='HWA 10')
# plt.plot(xaxis, runhwasgd['Train Acc.'], label='HWA SGD')
plt.title('Train Acc.')
plt.grid(True)
plt.legend()
# Out:
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:12: FutureWarning: read_table is deprecated, use read_csv instead.
#   if sys.path[0] == '':
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:13: FutureWarning: read_table is deprecated, use read_csv instead.
#   del sys.path[0]

# %%
num_epochs=6
every = len(runhwa10['Train Loss'])/num_epochs
#adam = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_optadam_lr0.001_bs128.txt'
#sgd = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_optsgd_lr0.01_bs128.txt'
#hwa = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_opthwa_lr0.001_bs128.txt'
#hwasgd = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_opthwa_sgd_lr0.02_bs128.txt'
hwa50 = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_opthwa_lr0.001_bs128_avgp100.txt'
hwa10 = 'checkpoint/checkpoint_MNIST/trainlogLeNet5_opthwa_lr0.001_bs128_avgp10.txt'

#runadam = pd.read_table(adam, index_col = 0, sep = '\t')
#runsgd = pd.read_table(sgd, index_col = 0, sep = '\t')
#runhwa = pd.read_table(hwa, index_col = 0, sep = '\t')
# runhwasgd = pd.read_table(hwasgd, index_col = 0, sep = '\t')
runhwa50 = pd.read_table(hwa50, index_col = 0, sep = '\t')
runhwa10 = pd.read_table(hwa10, index_col = 0, sep = '\t')


xaxis = range(num_epochs)
f, axs = plt.subplots(2,2,figsize=(10,5))
plt.tight_layout()
plt.subplot(1, 2, 1)
# plt.plot(xaxis, runadam['Train Loss'], label='Adam')
# plt.plot(xaxis, runsgd['Train Loss'], label='SGD')
# plt.plot(xaxis, runhwa['Train Loss'], label='HWA')
plt.plot(xaxis, runhwa50['Train Loss'].iloc[::every], label='HWA 50')
plt.plot(xaxis, runhwa10['Train Loss'].iloc[::every], label='HWA 10')
# plt.plot(xaxis, runhwasgd['Train Loss'], label='HWA SGD')

plt.title('Train Loss')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
# plt.plot(xaxis, runadam['Train Acc.'], label='Adam')
# plt.plot(xaxis, runsgd['Train Acc.'], label='SGD')
# plt.plot(xaxis, runhwa['Train Acc.'], label='HWA')
plt.plot(xaxis, runhwa50['Train Acc.'].iloc[::every], label='HWA 50')
plt.plot(xaxis, runhwa10['Train Acc.'].iloc[::every], label='HWA 10')
# plt.plot(xaxis, runhwasgd['Train Acc.'], label='HWA SGD')
plt.title('Train Acc.')
plt.grid(True)
plt.legend()
# Out:
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:14: FutureWarning: read_table is deprecated, use read_csv instead.
#
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:15: FutureWarning: read_table is deprecated, use read_csv instead.
#   from ipykernel import kernelapp as app

# %% [markdown]
# ### Testing

# %%
adam = 'checkpoint/checkpoint_MNIST/testlogLeNet5_optadam_lr0.001_bs128.txt'
sgd = 'checkpoint/checkpoint_MNIST/testlogLeNet5_optsgd_lr0.01_bs128.txt'
hwa = 'checkpoint/checkpoint_MNIST/testlogLeNet5_opthwa_lr0.001_bs128.txt'
hwasgd = 'checkpoint/checkpoint_MNIST/testlogLeNet5_opthwa_sgd_lr0.02_bs128.txt'
hwa50 = 'checkpoint/checkpoint_MNIST/testlogLeNet5_opthwa_lr0.001_bs128_avgp50.txt'
hwa10 = 'checkpoint/checkpoint_MNIST/testlogLeNet5_opthwa_lr0.001_bs128_avgp10.txt'

runadam = pd.read_table(adam, index_col = 0, sep = '\t')
runsgd = pd.read_table(sgd, index_col = 0, sep = '\t')
runhwa = pd.read_table(hwa, index_col = 0, sep = '\t')
runhwa50 = pd.read_table(hwa50, index_col = 0, sep = '\t')
runhwa10 = pd.read_table(hwa10, index_col = 0, sep = '\t')
runhwasgd = pd.read_table(hwasgd, index_col = 0, sep = '\t')


xaxis = range(len(runhwa50['Test Loss']))
f, axs = plt.subplots(2,2,figsize=(10,5))
plt.tight_layout()
plt.subplot(1, 2, 1)
plt.plot(xaxis, runadam['Test Loss'], label='Adam')
plt.plot(xaxis, runsgd['Test Loss'], label='SGD')
plt.plot(xaxis, runhwa['Test Loss'], label='HWA')
plt.plot(xaxis, runhwa50['Test Loss'], label='HWA 50')
plt.plot(xaxis, runhwa10['Test Loss'], label='HWA 10')
plt.plot(xaxis, runhwasgd['Test Loss'], label='HWA SGD')

plt.title('Test Loss')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(xaxis, runadam['Test Acc.'], label='Adam')
plt.plot(xaxis, runsgd['Test Acc.'], label='SGD')
plt.plot(xaxis, runhwa['Test Acc.'], label='HWA')
plt.plot(xaxis, runhwa50['Test Acc.'], label='HWA 50')
plt.plot(xaxis, runhwa10['Test Acc.'], label='HWA 10')
plt.plot(xaxis, runhwasgd['Test Acc.'], label='HWA SGD')
plt.title('Test Acc.')
plt.grid(True)
plt.legend()

# %% [markdown]
# #### More Epochs

# %%
adam = 'checkpoint/checkpoint_MNIST/testlogLeNet5_optadam_lr0.001_bs128.txt'
sgd = 'checkpoint/checkpoint_MNIST/testlogLeNet5_optsgd_lr0.01_bs128.txt'
hwa = 'checkpoint/checkpoint_MNIST/testlogLeNet5_opthwa_lr0.001_bs128.txt'
hwasgd = 'checkpoint/checkpoint_MNIST/testlogLeNet5_opthwa_sgd_lr0.02_bs128.txt'
hwa50 = 'checkpoint/checkpoint_MNIST/testlogLeNet5_opthwa_lr0.001_bs128_avgp100.txt'
hwa10 = 'checkpoint/checkpoint_MNIST/testlogLeNet5_opthwa_lr0.001_bs128_avgp10.txt'

# runadam = pd.read_table(adam, index_col = 0, sep = '\t')
# runsgd = pd.read_table(sgd, index_col = 0, sep = '\t')
# runhwa = pd.read_table(hwa, index_col = 0, sep = '\t')
runhwa50 = pd.read_table(hwa50, index_col = 0, sep = '\t')
runhwa10 = pd.read_table(hwa10, index_col = 0, sep = '\t')
# runhwasgd = pd.read_table(hwasgd, index_col = 0, sep = '\t')


xaxis = range(6)
f, axs = plt.subplots(2,2,figsize=(10,5))
plt.tight_layout()
plt.subplot(1, 2, 1)
# plt.plot(xaxis, runadam['Test Loss'], label='Adam')
# plt.plot(xaxis, runsgd['Test Loss'], label='SGD')
# plt.plot(xaxis, runhwa['Test Loss'], label='HWA')
plt.plot(xaxis, runhwa50['Test Loss'].iloc[::79], label='HWA 50')
plt.plot(xaxis, runhwa10['Test Loss'].iloc[::79], label='HWA 10')
# plt.plot(xaxis, runhwasgd['Test Loss'], label='HWA SGD')

plt.title('Test Loss')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
# plt.plot(xaxis, runadam['Test Acc.'], label='Adam')
# plt.plot(xaxis, runsgd['Test Acc.'], label='SGD')
# plt.plot(xaxis, runhwa['Test Acc.'], label='HWA')
plt.plot(xaxis, runhwa50['Test Acc.'].iloc[::79], label='HWA 50')
plt.plot(xaxis, runhwa10['Test Acc.'].iloc[::79], label='HWA 10')
# plt.plot(xaxis, runhwasgd['Test Acc.'], label='HWA SGD')
plt.title('Test Acc.')
plt.grid(True)
plt.legend()
# Out:
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:11: FutureWarning: read_table is deprecated, use read_csv instead.
#   # This is added back by InteractiveShellApp.init_path()
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:12: FutureWarning: read_table is deprecated, use read_csv instead.
#   if sys.path[0] == '':

# %%
adam = 'checkpoint/checkpoint_MNIST/testlogLeNet5_optadam_lr0.001_bs128.txt'
sgd = 'checkpoint/checkpoint_MNIST/testlogLeNet5_optsgd_lr0.01_bs128.txt'
hwa = 'checkpoint/checkpoint_MNIST/testlogLeNet5_opthwa_lr0.001_bs128.txt'
hwasgd = 'checkpoint/checkpoint_MNIST/testlogLeNet5_opthwa_sgd_lr0.02_bs128.txt'
hwa50 = 'checkpoint/checkpoint_MNIST/testlogLeNet5_opthwa_lr0.001_bs128_avgp100.txt'
hwa10 = 'checkpoint/checkpoint_MNIST/testlogLeNet5_opthwa_lr0.001_bs128_avgp10.txt'

# runadam = pd.read_table(adam, index_col = 0, sep = '\t')
# runsgd = pd.read_table(sgd, index_col = 0, sep = '\t')
# runhwa = pd.read_table(hwa, index_col = 0, sep = '\t')
runhwa50 = pd.read_table(hwa50, index_col = 0, sep = '\t')
runhwa10 = pd.read_table(hwa10, index_col = 0, sep = '\t')
# runhwasgd = pd.read_table(hwasgd, index_col = 0, sep = '\t')


xaxis = range(len(runhwa10['Test Loss']))
f, axs = plt.subplots(2,2,figsize=(10,5))
plt.tight_layout()
plt.subplot(1, 2, 1)
# plt.plot(xaxis, runadam['Test Loss'], label='Adam')
# plt.plot(xaxis, runsgd['Test Loss'], label='SGD')
# plt.plot(xaxis, runhwa['Test Loss'], label='HWA')
plt.plot(xaxis, runhwa50['Test Loss'], label='HWA 50')
plt.plot(xaxis, runhwa10['Test Loss'], label='HWA 10')
# plt.plot(xaxis, runhwasgd['Test Loss'], label='HWA SGD')

plt.title('Test Loss')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
# plt.plot(xaxis, runadam['Test Acc.'], label='Adam')
# plt.plot(xaxis, runsgd['Test Acc.'], label='SGD')
# plt.plot(xaxis, runhwa['Test Acc.'], label='HWA')
plt.plot(xaxis, runhwa50['Test Acc.'], label='HWA 50')
plt.plot(xaxis, runhwa10['Test Acc.'], label='HWA 10')
# plt.plot(xaxis, runhwasgd['Test Acc.'], label='HWA SGD')
plt.title('Test Acc.')
plt.grid(True)
plt.legend()
# Out:
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:11: FutureWarning: read_table is deprecated, use read_csv instead.
#   # This is added back by InteractiveShellApp.init_path()
# /Users/karimimohammedbelhal/Desktop/ML_Research/masterenv/lib/python2.7/site-packages/ipykernel_launcher.py:12: FutureWarning: read_table is deprecated, use read_csv instead.
#   if sys.path[0] == '':

# %%
with open ('params/trained_weights', 'rb') as fp:
    trained_weights = torch.load(fp)
with open ('params/init_weights', 'rb') as fp:
    init_weights = torch.load(fp)
init_weights = init_weights.detach().numpy()

# %%
weights = list(map(list, zip(*trained_weights)))

# %%
scalarindex = 2 #between 0 and 9 (since fc1 output)
weights = []
for element in trained_weights:
        weights.append(element[scalarindex])
weights = list(map(list, zip(*weights)))

# %% [markdown]
# # Plot distance for N neurons (not averaged)

# %%
dim = 3 #scalar weight index
for dim in range(200,203):
    distanceweights = [x - init_weights[scalarindex][dim] for x in weights[dim]] 
    xaxis = range(1,len(distanceweights)+1)
    plt.plot(xaxis, distanceweights)
    plt.grid(True)
    plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e2e5ff568289> in <module>()
#       1 dim = 3 #scalar weight index
#       2 for dim in range(200,203):
# ----> 3     distanceweights = [x - init_weights[scalarindex][dim] for x in weights[dim]]
#       4     xaxis = range(1,len(distanceweights)+1)
#       5     plt.plot(xaxis, distanceweights)
#
# NameError: name 'weights' is not defined

# %%
dim = 3 #scalar weight index
for dim in range(200,203):
    distanceweights = [x - init_weights[scalarindex][dim] for x in weights[dim]] 
    xaxis = range(1,len(distanceweights)+1)
    plt.plot(xaxis, distanceweights)
    plt.grid(True)
    plt.legend()

# %% [markdown]
# # Plot average distance for N neurons

# %%
def mean(a):
    return sum(a) / len(a)

scalarindex = 9
distanceweights=[]
N_neurons = 2000
for dim in range(N_neurons):
    distanceweights.append([(x - init_weights[scalarindex][dim])**2 for x in weights[dim]] )
distanceweights = map(mean, zip(*distanceweights))
xaxis = range(1,len(distanceweights)+1)
plt.plot(xaxis, distanceweights)
plt.grid(True)
plt.legend()
